# %% [markdown]
# <a href="https://colab.research.google.com/github/BrianLearning-source/PCVK_Genap_2026/blob/main/TugasKelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ASSIGNMENT GROUP PRACTICUM
# 03. Angelina Thennessa Jo
# 06. Brian Serafino Donovan

# %% [markdown]
# Integrate with Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Upload the Student Card to Google Drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a3ece6f8-1bd8-46fa-92cd-77c90d5d8f7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a3ece6f8-1bd8-46fa-92cd-77c90d5d8f7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Take the image from google Drive and display the image as output here

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/foto KTM.jpg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
cv2.rectangle(img,pt1=(180,50), pt2=(520,180),color=(0,0,0),thickness=3)
cv2.line(img, (180,50), (520, 180), (255,255,255), 5)
cv2.line(img, (180,180), (520, 50), (255,255,255), 5)
cv2.rectangle(img,pt1=(180,110), pt2=(520,180),color=(0,0,0),thickness=-1)
cv2.circle(img,center=(1125,550),radius=100,color=(255,0,0),thickness=-1)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
